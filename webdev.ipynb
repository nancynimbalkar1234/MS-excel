# %% [markdown]
# <a href="https://colab.research.google.com/github/nancynimbalkar1234/MS-excel/blob/main/webdev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day2.html

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <div align="center">
        <!-- Inline CSS -->
        <h1 style="background-color: crimson;
        font-size: 40px;color:white;
        font-family:'Lucida Sans', 'Lucida Sans Regular', 'Lucida Grande', 'Lucida Sans Unicode', Geneva, Verdana, sans-serif;
        text-align: center;

       ">Introduction to HTML tags</h1>
        <!-- Paragraph Tag -->
        <p style="color:darkcyan">Support learning with Google Workspace for Education's simple, secure and flexible tools <b>Help your institution to collaborate easily,</b><br> streamline instruction and keep the learning environment safer with tools designed for students and teachers</p>
    </div>
         <div align="right">
        <img src="https://images.pexels.com/photos/5480518/pexels-photo-5480518.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1" width="800px" height="500px" > <br>

        <img  src="static.wikia.nocookie.net/onepiece/images/6/64/Roronoa_Zoro_Anime_Pre_Timeskip_Infobox.png/revision/latest?cb=20220916" alt="Wrong content" >
    </div>



</body>
</html>
# Out:
#   File "<tokenize>", line 16
#     ">Introduction to HTML tags</h1>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Class 4

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
   <link href="external.css" rel="stylesheet">

</head>
<body>
    <h1 id="a" class="b">Introduction to css</h1>
    <h1 class="c b">Introduction to Internal CSS</h1>
    <h1 class="b">Introduction to External CSS</h1>
    <!-- Anchor -->
    <a href="https://about.fb.com/wp-content/uploads/2020/05/NRP-the_new_facebook.com-final-1.jpg">Facebook</a>

    <div id="box">
        <h6>Hello</h6>
    </div>
</body>
</html>
# Out:
#   File "<tokenize>", line 7
#     <link href="external.css" rel="stylesheet">
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# External file



#a{
    background-color: aquamarine;
    text-align: center;
    color: brown;
    text-shadow: 2px 2px white;
}
.c{
    background-color: burlywood;
    color:green;
    text-align: center;
    text-shadow: 2px 2px white;

}
.b{
    /* Box model */
    margin-right: 120px;
    border-style: double;
    border-width: 5px;
    border-color: black;
    padding:20px;
    border-radius: 120px;
    box-shadow: 10px 10px 10px black ;
}
body{
    /* background-color: blue; */
    background-image: url("https://images.pexels.com/photos/9907228/pexels-photo-9907228.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1");
    background-size: cover;
}
#box{
    width:200px;
    height:200px;
    /* background-color: blue; */
    background-image: linear-gradient(120deg,red,white,blue,green);
    border-radius: 120px;
}
h6{
    font-size: 22px;
    text-align: center;
    padding-top:80px;

}
# Out:
#   File "<ipython-input-1-e78b91de5b63>", line 6
#     background-color: aquamarine;
#     ^
# IndentationError: unexpected indent

# %%
# Day 6

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        /* body{
            background-color: blue;
            background-image: url("https://images.pexels.com/photos/5138926/pexels-photo-5138926.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1");
            background-size: cover;

        } */

        #a{
            /* background-size: cover; */
            width:100%;
            height:100%;
            opacity: 0.6;
        }
        header{
            /* position: absolute; */
            position: fixed;
            left:0px;
            top:0px;
            font-size: 40px;
            color:white;
            /* background-image: linear-gradient(rgb(169, 102, 102),rgb(116, 187, 116),rgb(77, 77, 126),pink,rgb(236, 193, 115),rgb(214, 214, 144)); */
            background-color: black;
            width:100%;
            text-shadow: 2px 2px red;
           font-family: 'Lucida Sans', 'Lucida Sans Regular', 'Lucida Grande', 'Lucida Sans Unicode', Geneva, Verdana, sans-serif;
           word-spacing: 20px;
        }
        footer{
            position: fixed;
            left:0px;
            bottom:0px;
            font-size: 40px;
            color:white;
            /* background-image: linear-gradient(rgb(169, 102, 102),rgb(116, 187, 116),rgb(77, 77, 126),pink,rgb(236, 193, 115),rgb(214, 214, 144)); */
            background-color: black;
            width:100%;
            text-shadow: 2px 2px red;
           font-family: 'Lucida Sans', 'Lucida Sans Regular', 'Lucida Grande', 'Lucida Sans Unicode', Geneva, Verdana, sans-serif;
           word-spacing: 20px;
        }
        #b{
            background-color: aqua;
            width:200px;
            height:200px;
            position: absolute;
            left:150px;
            top:200px;


        }
        h5{
            color:white;
            text-shadow: 1px 1px black;
            margin: 20px;

        }
    </style>
</head>
<body>
    <div align="center">
        <img src="https://images.pexels.com/photos/5138926/pexels-photo-5138926.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1" id="a">
        <header>Welcome to webpage</header>
        <footer>Thank you </footer>
        <h5 id="b">Box</h5>
    </div>
</body>
</html>
# Out:
#   File "<tokenize>", line 34
#     font-family: 'Lucida Sans', 'Lucida Sans Regular', 'Lucida Grande', 'Lucida Sans Unicode', Geneva, Verdana, sans-serif;
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Day 7


<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        body{
            background-color:#edede9;

        }

        #box{
            background-color: chartreuse;
            /* background-image: url("https://images.pexels.com/photos/6583558/pexels-photo-6583558.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1"); */
            background-size: cover;
            width: 200px;
            height:200px;
            box-shadow: 10px 10px 10px ;
            border-radius: 12px;
            /* position: absolute;
            left:120px; */
            /* margin-left:440px; */
            /* text-indent:150px ; */
            animation-name:anim ;
            animation-duration: 2s;
            animation-iteration-count: infinite;
            position: relative;
            /* animation-delay: 3s; */
        }
        h4{
            color:red;
        }
        @keyframes anim{
            /* from{background-color: aqua;}to{background-color:rgb(255, 123, 0);} */
            /* 10%{background-color: blue;left:0px;top:0px;color:white;font-size: 30px;}
            20%{background-color: rgb(0, 255, 17);left:200px;top:0px;color:rgb(229, 33, 33);font-size: 50px;}
            30%{background-color: rgb(255, 0, 0);left:200px;top:200px;color:rgb(9, 9, 9);font-size: 40px;}
            40%{background-color: rgb(255, 0, 217);left:0px;top:200px;color:rgb(206, 23, 23);font-size: 60px;}
            50%{background-color: rgb(0, 251, 255);left:0px;top:0px;color:rgb(255, 255, 255);font-size: 40px;} */


            /* rotate */
            /* 10%{transform:rotate(0) ;}
            40%{transform: rotate(90deg);}
            60%{transform: rotate(180deg);}
            80%{transform: rotate(260deg);}
            100%{transform: rotate(360deg);} */

            1%{opacity: 0;}
            2%{opacity: 0.2;}
            3%{opacity: 0.5;}
            4%{opacity: 0.7;}
            5%{opacity: 1;}
        }

    </style>

</head>
<body>

    <div id="box">
     <h4>Thank you</h4>

</div>

</body>
</html>
# Out:
#   File "<ipython-input-1-9684f8c34443>", line 20
#     width: 200px;
#              ^
# SyntaxError: invalid decimal literal

# %%
# Day 8
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
 <link href="a.css" rel="stylesheet">
</head>
<body>
    <div class="maindiv">
        <div id="a">
           <video src="video.mp4" controls ="200px" height="150px"></video>
        </div>
        <div id="b">
            <audio src="Audio.mp3" controls></audio>
        </div>
        <div id="c">Link</div>
        <div id="d">Events</div>
        <div id="e">Support</div>
    </div>
</body>
</html>



# External css

/* #a{grid-area: a1;}
#b{grid-area: b1;}
#c{grid-area: c1;}
#d{grid-area: d1;}
#e{grid-area: e1;} */

.maindiv{
    display:flex;
    flex-direction: row;
    /* grid-template-areas:
    'a '
    'd1 d1 d1 d1 e1'; */
    text-align: center;
    background-image: url("https://images.pexels.com/photos/556414/pexels-photo-556414.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1");
    background-size: cover;
    padding:20px;
    margin:20px;
    border-radius: 20px;
    font-size: 30px;
    color:white;
}
div{
    background-color: antiquewhite;
    padding:20px;
    border-radius: 20px;
    margin:20px;
    color:black;
    text-shadow: 2px 2px white;
    font-family: 'Trebuchet MS', 'Lucida Sans Unicode', 'Lucida Grande', 'Lucida Sans', Arial, sans-serif;
    box-shadow: 5px 5px black;
}



# scrollable


<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
#a1{
    display: flex;
    overflow-x: scroll;
}
#a{
     flex:0 0 auto;
    width:200px;
    height:200px;
    background-color: aquamarine;
}
    </style>
</head>
<body>
    <div id="a1">
    <div id="a">Link</div>
    <div id="a">Link</div>
    <div id="a">Link</div>
    <div id="a">Link</div>
      <div id="a">Link</div>
      <div id="a">Link</div>
      <div id="a">Link</div>
      <div id="a">Link</div>
      <div id="a">Link</div>
        <div id="a">Link</div>
    </div>

</body>
</html>
# Out:
#   File "<tokenize>", line 8
#     <link href="a.css" rel="stylesheet">
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Day9,10
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet" >
    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.10.5/font/bootstrap-icons.css">
    <style>
        .a{
            color:white;
            font-size: 22px;
        }
    </style>
</head>
<body>
    <h1 class="bg-secondary">Introduction to bootstrap</h1>
<!-- <button class="btn btn-secondary">Click here!</button> -->
<div class="container text-center">
    <div class="row">
      <div class="col bg-primary m-2">
        Name
      </div>
      <div class="col bg-warning m-2">
        Course
      </div>
      <div class="col bg-info m-2">
        Status
      </div>
    </div>
  </div>
  <div class="container text-center">
    <div class="row ">
      <div class="col bg-light  m-2">
        Tom
      </div>
      <div class="col bg-light  m-2">
        Web development
      </div>
      <div class="col  bg-success  m-2 a">
        Completed <i class="bi bi-check-lg a"></i>
      </div>
    </div>
  </div>
  <div class="container text-center">
    <div class="row ">
      <div class="col  bg-light  m-2">
        Jerry
      </div>
      <div class="col  bg-light  m-2">
        Advance web development
      </div>
      <div class="col  bg-danger  m-2 a">
        Incomplete <i class="bi bi-x-lg a"></i>
      </div>
    </div>
  </div>

</body>
</html>
# Out:
#   File "<tokenize>", line 32
#     </div>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Day 11
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet" >
    <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
    <style>
        .a{
            position: absolute;
            top:15px;
            left:40vmax;
            font-size: 27px;
            background-color: #0A66C2;
        }
    </style>
</head>
<body>
    <!-- <div align="center">
        <ul type="none">
            <li>Data </li>
            <li>Events </li>
            <li>About</li>
            <li> List</li>
        </ul>
    </div> -->
    <nav class="navbar navbar-expand-lg bg-warning">
        <div class="container-fluid">
          <a class="navbar-brand" href="#">Navbar</a>
          <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
            <span class="navbar-toggler-icon"></span>
          </button>
          <div class="collapse navbar-collapse" id="navbarNav">
            <ul class="navbar-nav">
              <li class="nav-item">
                <a class="nav-link active" aria-current="page" href="#">Home</a>
              </li>
              <li class="nav-item">
                <a class="nav-link" href="#">Features</a>
              </li>
              <li class="nav-item">
                <a class="nav-link" href="#">Pricing</a>
              </li>
              <li class="nav-item">
                <a class="nav-link disabled">Disabled</a>
              </li>
            </ul>
          </div>
        </div>
      </nav>
      <i class="fa-brands fa-linkedin a"></i>
</body>
</html>
# Out:
#   File "<tokenize>", line 52
#     </nav>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# API
const server = require("express");// import express

const app = server();//create Express Application On the App VAriable  -  used to understand the various function
app.use(server.json()); //Used The JSON FIle(javascipt object notation)


// port environment variable
const port =5678;
app.listen(port, () => console.log('listining on Port '+ port));// we will use this command to list the server to the port.

//give the data to the server
const T1 = [
    {title: 'George', id: 1},
    {title: 'Josh', id: 2},
    {title: 'tyler', id: 3},
    {title: 'Alice', id: 4},
    {title: 'Candice', id: 5}
]

const T2 = [
    {title: 'A', id: 6},
    {title: 'A', id: 7},
]

const T3 = [
    {title: 'A', id: 8},
    {title: 'w', id: 9},
]
//read request handelers
//display the message when the url consists of '/'
app.get('/welcome', (req,res ) => {                    //read the resource
    res.send('Welcome To My First Api Get Request');
})


//display the list of customers when the URL request Consists of api customer
app.get('/a', (req,res) => {
    res.send(T1);
});

app.get('/T2', (req,res) => {
    res.send(T2);
});

app.get('/T3', (req,res) => {
    res.send(T3);
});
# Out:
#   File "<ipython-input-1-a625d898b871>", line 2
#     const server = require("express");// import express
#           ^
# SyntaxError: invalid syntax

# %%
# Interactive
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Age & Distance Converter</title>
    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
    <style>
        body {
            font-family: Arial, sans-serif;
            background-color: #f8f9fa;
        }

        .container {
            max-width: 800px;
            margin: 50px auto;
            padding: 20px;
            border-radius: 10px;
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
            background-color: #fff;
        }

        .header {
            background: linear-gradient(135deg, #1877f2, #1877f2, #1877f2);
            color: #fff;
            text-align: center;
            padding: 20px;
            margin-bottom: 20px;
        }

        .footer {
            background: linear-gradient(135deg, #1877f2, #1877f2, #1877f2);
            color: #fff;
            text-align: center;
            padding: 20px;
            position: fixed;
            bottom: 0;
            left: 0;
            width: 100%;
        }

        h1 {
            font-size: 24px;
            margin-bottom: 20px;
        }

        .converter-section {
            padding: 20px;
            border-radius: 10px;
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
            margin-bottom: 20px;
            background-color: #fff;
            height: 100%;
        }

        .result {
            margin-top: 20px;
        }

        .result p {
            font-weight: bold;
            margin-bottom: 5px;
        }
    </style>
</head>
<body>
    <div class="header">
        <h1>Age & Distance Converter</h1>
    </div>

    <div class="container">
        <div class="row">
            <div class="col-md-6">
                <div class="converter-section">
                    <h2>Age Calculator</h2>
                    <div class="form-group">
                        <label for="dob">Date of Birth:</label>
                        <input type="date" id="dob" class="form-control">
                    </div>
                    <button class="btn btn-primary mt-3" onclick="calculateAge()">Calculate Age</button>
                    <div class="result">
                        <p>Age in years: <span id="years"></span></p>
                        <p>Age in months: <span id="months"></span></p>
                        <p>Age in hours: <span id="hours"></span></p>
                        <p>Age in minutes: <span id="minutes"></span></p>
                        <p>Age in seconds: <span id="seconds"></span></p>
                    </div>
                </div>
            </div>
            <div class="col-md-6">
                <div class="converter-section">
                    <h2>Distance Converter</h2>
                    <div class="form-group">
                        <label for="distance">Distance:</label>
                        <input type="number" id="distance" class="form-control">
                    </div>
                    <div class="form-group">
                        <label for="unit">Unit:</label>
                        <select id="unit" class="form-control">
                            <option value="km">Kilometers</option>
                            <option value="m">Meters</option>
                            <option value="in">Inches</option>
                        </select>
                    </div>
                    <button class="btn btn-primary mt-3" onclick="convertDistance()">Convert</button>
                    <div class="result">
                        <p>Distance in kilometers: <span id="km"></span></p>
                        <p>Distance in meters: <span id="m"></span></p>
                        <p>Distance in inches: <span id="in"></span></p>
                    </div>
                </div>
            </div>
        </div>
    </div>

    <div class="footer">
        <p>© 2023 Age & Distance Converter. All rights reserved.</p>
    </div>

    <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
    <script>
        function calculateAge() {
            var dob = document.getElementById('dob').value;
            var today = new Date();
            var birthDate = new Date(dob);
            var ageInYears = today.getFullYear() - birthDate.getFullYear();
            var ageInMonths = (ageInYears * 12) + (today.getMonth() - birthDate.getMonth());
            var ageInHours = ageInYears * 365 * 24;
            var ageInMinutes = ageInYears * 365 * 24 * 60;
            var ageInSeconds = ageInYears * 365 * 24 * 60 * 60;

            document.getElementById('years').textContent = ageInYears;
            document.getElementById('months').textContent = s;
            document.getElementById('hours').textContent = ageInHours;
            document.getElementById('minutes').textContent = ageInMinutes;
            document.getElementById('seconds').textContent = ageInSeconds;
        }ageInMonth

        function convertDistance() {
            var distance = document.getElementById('distance').value;
            var unit = document.getElementById('unit').value;

            if (unit === 'km') {
                document.getElementById('km').textContent = distance;
                document.getElementById('m').textContent = distance * 1000;
                document.getElementById('in').textContent = distance * 39370.1;
            } else if (unit === 'm') {
                document.getElementById('km').textContent = distance / 1000;
                document.getElementById('m').textContent = distance;
                document.getElementById('in').textContent = distance * 39.3701;
            } else if (unit === 'in') {
                document.getElementById('km').textContent = distance / 39370.1;
                document.getElementById('m').textContent = distance / 39.3701;
                document.getElementById('in').textContent = distance;
            }
        }
    </script>
</body>
</html>
